# %% [markdown]
# # Simple Spectra Tools

# %%
# %matplotlib notebook

# %%
# imports
import numpy as np
from matplotlib import pyplot as plt

from linetools.spectra import xspectrum1d

# %% [markdown]
# # Dummy spectrum

# %%
wave = 5000. + np.arange(3000)
wave
# Out:
# array([5000., 5001., 5002., ..., 7997., 7998., 7999.])

# %%
flux = np.random.uniform(size=wave.size)
flux
# Out:
# array([0.59161669, 0.58097999, 0.19720844, ..., 0.11097528, 0.5137308 ,
#        0.04452477])

# %% [markdown]
# # Using matplotlib (boring)

# %%
plt.clf()
ax = plt.gca()
ax.plot(wave, flux)
#
ax.set_xlabel('Wavelength (Ang)')
ax.set_ylabel('Flux')
#
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7129449315802">

# %% [markdown]
# # Using linetools
#     https://linetools.readthedocs.io/en/latest/

# %%
xspec = xspectrum1d.XSpectrum1D.from_tuple((wave,flux))
# Out:
# /home/xavier/local/Python/linetools/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")

# %% [markdown]
# ## In the Notebook

# %%
xspec.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.7129449315802">

# %% [markdown]
# ## The real deal
#     See these docs:  https://github.com/linetools/linetools/blob/master/docs/xspecgui.rst

# %%
xspec.plot(xspec=True)
# Out:
# /home/xavier/local/Python/linetools/linetools/spectra/xspectrum1d.py:355: UserWarning: This spectrum does not contain an input error array
#   warnings.warn("This spectrum does not contain an input error array")
